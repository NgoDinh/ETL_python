# %%
import os
import json
import zipfile
import pandas as pd
from os import listdir
from os.path import isfile, join
from google.cloud import bigquery

client = bigquery.Client.from_service_account_json('google_token.json')
job_config_trans = bigquery.LoadJobConfig(
	schema=[
        bigquery.SchemaField('Bill_Outlier__Outlier_Status', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Date__date', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Time__time', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__user_id', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__slab_name', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__fraud_status', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__mobile', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__loyalty_type', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__email', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__last_name', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__first_name', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Store_Hierarchy__Store_Name', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Concept_Hierarchy__concept_name', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Product__brand_name', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Product__color', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Product__size', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Product__style', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Product__inventory_description', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Product__image_url', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Product__price', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Product__item_code', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Product__Item_Id', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Line_Item_Outlier__Outlier_Status', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('line_item_type__Line_Item_Type', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Loyalty__Loyalty_Type', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('membership__Membership_Type', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Repeat__Repeat_Status', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Source__Source_Type', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Additional_Discount', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Allocated_Points', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Auto_Update_Time_Bill', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Auto_Update_Time_Bill_Extended_Fields', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Auto_Update_Time_Combo_Details', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Auto_Update_Time_Lineitem', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Auto_Update_Time_Lineitem_Extended_Fields', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Auto_Update_Time_Shipping', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Bill_Amount', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Bill_Discount', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Bill_Number', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Central_Gst', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Converted_Bill_Id', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Days_Since_Last_Visit', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Description', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Initial_Bill_Value', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Initial_Line_Item_Value', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Integrated_Gst', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Items_In_Product_Set', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Item_Code', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Item_Coupon_Discount', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Item_Discount_Description', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Item_Point_Discount', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Item_Unit_Margin', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Lineitem_Central_Gst', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Lineitem_Integrated_Gst', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Lineitem_Serial_Number', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Lineitem_Service_Tax_Amount', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Lineitem_Service_Tax_Percentage', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Lineitem_Size', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Lineitem_State_Gst', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Lineitem_Uuid', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Lineitem_Vat_Amount', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Lineitem_Vat_Tax_Percentage', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Line_Item_Amount', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Line_Item_Discount', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Notes', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Parent_Line_Item_Id', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Quantity', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Rate', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Reason', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Redeemed_Points', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('State_Gst', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Tax_Amount', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Total_Quantity', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Total_Unit_Cost', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Visit_Count', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Visit_Day_Count', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Bill_Id', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Line_Item_Id', bigquery.enums.SqlTypeNames.STRING)
    ],
    write_disposition="WRITE_TRUNCATE",
)
job_config_point = bigquery.LoadJobConfig(
	schema=[
        bigquery.SchemaField('category__redemption_type', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('deduction_type__Deduction_Type', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Date__date', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Time__time', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__user_id', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__slab_name', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__fraud_status', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__mobile', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__loyalty_type', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__email', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__last_name', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__first_name', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Store_Hierarchy__Store_Name', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Concept_Hierarchy__concept_name', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('points_awarded_type__Points_Awarded_Type', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('points_event_type__Points_Event_Type', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('points_promotion__Points_Promotion_Type', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Allocated_Points', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Auto_Update_Time_Pa', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Auto_Update_Time_Pabp', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Auto_Update_Time_Pacp', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Auto_Update_Time_Pal', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Auto_Update_Time_Palp', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Auto_Update_Time_Pd', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Awarded_Ref_Id', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Bill_Id', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Bill_Number', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Deducted_Points', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Deduction_Summary_Id', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Redemption_Bill_Id', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Redemption_Bill_Number', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Event_Id', bigquery.enums.SqlTypeNames.STRING)
    ],
    write_disposition="WRITE_TRUNCATE",
)
job_config_coupon = bigquery.LoadJobConfig(
	schema=[
        bigquery.SchemaField('campaign_group__group_type', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('campaign_group__group_name', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('campaign_group__roi_type', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('campaign__campaign_start_date', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('campaign__campaign_end_date', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('campaign__name', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('coupon_event_type__status', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('coupon_series__series_type', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('coupon_series__series_name', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('coupon_series__discount_code', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('entry_type__value', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Date__date', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Time__time', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__user_id', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__slab_name', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__fraud_status', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__mobile', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__loyalty_type', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__email', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__last_name', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__first_name', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Store_Hierarchy__Store_Name', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Concept_Hierarchy__concept_name', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('expiry_date__date', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Issual_Zone_Till__Store_Name', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Auto_Update_Time_Coupons', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Bill_Id', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Coupon_Code', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Coupon_Code_Src', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Issual_Coupon_Id', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Redemption_Bill_Amount', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Used_Bill_Number', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('Event_Id', bigquery.enums.SqlTypeNames.STRING)
    ],
    write_disposition="WRITE_TRUNCATE",
)
job_config_user = bigquery.LoadJobConfig(
	schema=[
        bigquery.SchemaField('User__user_id', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__slab_name', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__fraud_status', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__mobile', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__loyalty_type', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__email', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__last_name', bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField('User__first_name', bigquery.enums.SqlTypeNames.STRING)
    ],
    write_disposition="WRITE_TRUNCATE",
)

mypath = "C:\\Users\\vu.d.ngo\\upload_capi"
all_links = [join(mypath,f) for f in listdir(mypath) if isfile(join(mypath, f))]
all_file = [f.split(".")[0] for f in listdir(mypath) if isfile(join(mypath, f))]
all_name = [(i.split("__")[1], i.split("__")[2].replace("-","",2)[:8]) for i in all_file]
for x in range(len(all_links)):
    zip_link = all_links[x]
    file_name = all_file[x] + ".csv"
    zf = zipfile.ZipFile(zip_link)
    df = pd.read_csv(zf.open(file_name))
    json_list = json.loads(json.dumps(list(df.T.to_dict().values())))
    for i in json_list:
        for key in i.keys():
            i[key] = str(i[key])
            
    prefix = 'taptap-c2c5f.manual_dwh.capillary_'
    table_id = prefix + all_name[x][0] + "_" + all_name[x][1]
    if all_name[x][0] == "Coupons":
        job_config = job_config_coupon
    elif all_name[x][0] == "Points":
        job_config = job_config_point
    elif all_name[x][0] == "Transaction":
        job_config = job_config_trans
    elif all_name[x][0] == "Users":
        job_config = job_config_user

    print(table_id)
    job = client.load_table_from_json(
        json_list, table_id, job_config=job_config
    ) 
    print(job.result())
    
#close file   
zf.close()
#clear folder
for f in os.listdir(mypath):
    os.remove(os.path.join(mypath, f))
# Out:
# taptap-c2c5f.manual_dwh.capillary_Coupons_20220209
# LoadJob<project=taptap-c2c5f, location=US, id=7c2eb085-309f-4828-819f-3e7c6753c0d9>
# taptap-c2c5f.manual_dwh.capillary_Transaction_20220210
# LoadJob<project=taptap-c2c5f, location=US, id=67da696c-e319-4a12-bbef-3e885935d0c6>
# taptap-c2c5f.manual_dwh.capillary_Users_20220209
# LoadJob<project=taptap-c2c5f, location=US, id=80288504-ab6a-4fc4-b634-39c9ccd59b58>
# taptap-c2c5f.manual_dwh.capillary_Users_20220210
# LoadJob<project=taptap-c2c5f, location=US, id=e557df10-0739-4294-b2ed-9160104e7807>
